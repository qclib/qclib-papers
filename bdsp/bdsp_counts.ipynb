# %% [markdown]
# # BDSP CNOTs and depht
# ### Table 3 and Figure 6

# %% [markdown]
# # Qiskit config

# %%
import warnings
warnings.filterwarnings("ignore")

from qiskit import IBMQ, QuantumCircuit, ClassicalRegister, QuantumRegister, execute, Aer, transpile

backend = Aer.get_backend('qasm_simulator')

shots   = 8192
backend_name = backend.name()
backend_config = backend.configuration()
backend_qubits = backend_config.n_qubits

# %% [markdown]
# # Counting

# %%
import numpy as np
from qclib.state_preparation.bdsp import initialize

result = {}
for n in range(3, 16):
    print('\nn =', n)
    
    N = 2**n
    input_state = ((1.0 - 0.01) * np.random.rand(N) + 0.01) + ((1.0 - 0.01) * np.random.rand(N) + 0.01) * 1j
    input_state = input_state/np.linalg.norm(input_state)

    result[n] = []
    
    for s in range(1, n+1):
        circuit = initialize(input_state, s)
        transpiled_circuit = transpile(circuit, basis_gates=['u1','u2','u3', 'cx'], optimization_level=3)
        n_cx = transpiled_circuit.count_ops()['cx']
        n_dp = transpiled_circuit.depth()
        n_qb = len(circuit.qubits)
        
        result[n].append([s, n_cx, n_dp, n_qb])
        
        print('\t s = {0}\t CNOTs = {1}\t depth = {2}\t qubits = {3}'.format(s, n_cx, n_dp, n_qb))
# Out:
# n = 3
# 	 s = 1	 CNOTs = 28	 depth = 31	 qubits = 7
# 	 s = 2	 CNOTs = 18	 depth = 24	 qubits = 5
# 	 s = 3	 CNOTs = 10	 depth = 20	 qubits = 3
#
# n = 4
# 	 s = 1	 CNOTs = 77	 depth = 58	 qubits = 15
# 	 s = 2	 CNOTs = 57	 depth = 51	 qubits = 11
# 	 s = 3	 CNOTs = 41	 depth = 48	 qubits = 7
# 	 s = 4	 CNOTs = 26	 depth = 51	 qubits = 4
#
# n = 5
# 	 s = 1	 CNOTs = 182	 depth = 93	 qubits = 31
# 	 s = 2	 CNOTs = 142	 depth = 86	 qubits = 23
# 	 s = 3	 CNOTs = 110	 depth = 83	 qubits = 15
# 	 s = 4	 CNOTs = 80	 depth = 87	 qubits = 9
# 	 s = 5	 CNOTs = 58	 depth = 114	 qubits = 5
#
# n = 6
# 	 s = 1	 CNOTs = 399	 depth = 136	 qubits = 63
# 	 s = 2	 CNOTs = 319	 depth = 129	 qubits = 47
# 	 s = 3	 CNOTs = 255	 depth = 126	 qubits = 31
# 	 s = 4	 CNOTs = 195	 depth = 130	 qubits = 19
# 	 s = 5	 CNOTs = 151	 depth = 158	 qubits = 11
# 	 s = 6	 CNOTs = 122	 depth = 241	 qubits = 6
#
# n = 7
# 	 s = 1	 CNOTs = 840	 depth = 187	 qubits = 127
# 	 s = 2	 CNOTs = 680	 depth = 180	 qubits = 95
# 	 s = 3	 CNOTs = 552	 depth = 177	 qubits = 63
# 	 s = 4	 CNOTs = 432	 depth = 181	 qubits = 39
# 	 s = 5	 CNOTs = 344	 depth = 209	 qubits = 23
# 	 s = 6	 CNOTs = 286	 depth = 293	 qubits = 13
# 	 s = 7	 CNOTs = 250	 depth = 496	 qubits = 7
#
# n = 8
# 	 s = 1	 CNOTs = 1729	 depth = 246	 qubits = 255
# 	 s = 2	 CNOTs = 1409	 depth = 239	 qubits = 191
# 	 s = 3	 CNOTs = 1153	 depth = 236	 qubits = 127
# 	 s = 4	 CNOTs = 913	 depth = 240	 qubits = 79
# 	 s = 5	 CNOTs = 737	 depth = 268	 qubits = 47
# 	 s = 6	 CNOTs = 621	 depth = 352	 qubits = 27
# 	 s = 7	 CNOTs = 549	 depth = 556	 qubits = 15
# 	 s = 8	 CNOTs = 506	 depth = 1007	 qubits = 8
#
# n = 9
# 	 s = 1	 CNOTs = 3514	 depth = 313	 qubits = 511
# 	 s = 2	 CNOTs = 2874	 depth = 306	 qubits = 383
# 	 s = 3	 CNOTs = 2362	 depth = 303	 qubits = 255
# 	 s = 4	 CNOTs = 1882	 depth = 307	 qubits = 159
# 	 s = 5	 CNOTs = 1530	 depth = 335	 qubits = 95
# 	 s = 6	 CNOTs = 1298	 depth = 419	 qubits = 55
# 	 s = 7	 CNOTs = 1154	 depth = 623	 qubits = 31
# 	 s = 8	 CNOTs = 1068	 depth = 1075	 qubits = 17
# 	 s = 9	 CNOTs = 1018	 depth = 2030	 qubits = 9
#
# n = 10
# 	 s = 1	 CNOTs = 7091	 depth = 388	 qubits = 1023
# 	 s = 2	 CNOTs = 5811	 depth = 381	 qubits = 767
# 	 s = 3	 CNOTs = 4787	 depth = 378	 qubits = 511
# 	 s = 4	 CNOTs = 3827	 depth = 382	 qubits = 319
# 	 s = 5	 CNOTs = 3123	 depth = 410	 qubits = 191
# 	 s = 6	 CNOTs = 2659	 depth = 494	 qubits = 111
# 	 s = 7	 CNOTs = 2371	 depth = 698	 qubits = 63
# 	 s = 8	 CNOTs = 2199	 depth = 1150	 qubits = 35
# 	 s = 9	 CNOTs = 2099	 depth = 2106	 qubits = 19
# 	 s = 10	 CNOTs = 2042	 depth = 4077	 qubits = 10
#
# n = 11
# 	 s = 1	 CNOTs = 14252	 depth = 471	 qubits = 2047
# 	 s = 2	 CNOTs = 11692	 depth = 464	 qubits = 1535
# 	 s = 3	 CNOTs = 9644	 depth = 461	 qubits = 1023
# 	 s = 4	 CNOTs = 7724	 depth = 465	 qubits = 639
# 	 s = 5	 CNOTs = 6316	 depth = 493	 qubits = 383
# 	 s = 6	 CNOTs = 5388	 depth = 577	 qubits = 223
# 	 s = 7	 CNOTs = 4812	 depth = 781	 qubits = 127
# 	 s = 8	 CNOTs = 4468	 depth = 1233	 qubits = 71
# 	 s = 9	 CNOTs = 4268	 depth = 2189	 qubits = 39
# 	 s = 10	 CNOTs = 4154	 depth = 4161	 qubits = 21
# 	 s = 11	 CNOTs = 4090	 depth = 8172	 qubits = 11
#
# n = 12
# 	 s = 1	 CNOTs = 28581	 depth = 562	 qubits = 4095
# 	 s = 2	 CNOTs = 23461	 depth = 555	 qubits = 3071
# 	 s = 3	 CNOTs = 19365	 depth = 552	 qubits = 2047
# 	 s = 4	 CNOTs = 15525	 depth = 556	 qubits = 1279
# 	 s = 5	 CNOTs = 12709	 depth = 584	 qubits = 767
# 	 s = 6	 CNOTs = 10853	 depth = 668	 qubits = 447
# 	 s = 7	 CNOTs = 9701	 depth = 872	 qubits = 255
# 	 s = 8	 CNOTs = 9013	 depth = 1324	 qubits = 143
# 	 s = 9	 CNOTs = 8613	 depth = 2280	 qubits = 79
# 	 s = 10	 CNOTs = 8385	 depth = 4252	 qubits = 43
# 	 s = 11	 CNOTs = 8257	 depth = 8264	 qubits = 23
# 	 s = 12	 CNOTs = 8186	 depth = 16363	 qubits = 12
#
# n = 13
# 	 s = 1	 CNOTs = 57246	 depth = 661	 qubits = 8191
# 	 s = 2	 CNOTs = 47006	 depth = 654	 qubits = 6143
# 	 s = 3	 CNOTs = 38814	 depth = 651	 qubits = 4095
# 	 s = 4	 CNOTs = 31134	 depth = 655	 qubits = 2559
# 	 s = 5	 CNOTs = 25502	 depth = 683	 qubits = 1535
# 	 s = 6	 CNOTs = 21790	 depth = 767	 qubits = 895
# 	 s = 7	 CNOTs = 19486	 depth = 971	 qubits = 511
# 	 s = 8	 CNOTs = 18110	 depth = 1423	 qubits = 287
# 	 s = 9	 CNOTs = 17310	 depth = 2379	 qubits = 159
# 	 s = 10	 CNOTs = 16854	 depth = 4351	 qubits = 87
# 	 s = 11	 CNOTs = 16598	 depth = 8363	 qubits = 47
# 	 s = 12	 CNOTs = 16456	 depth = 16463	 qubits = 25
# 	 s = 13	 CNOTs = 16378	 depth = 32746	 qubits = 13
#
# n = 14
# 	 s = 1	 CNOTs = 114583	 depth = 768	 qubits = 16383
# 	 s = 2	 CNOTs = 94103	 depth = 761	 qubits = 12287
# 	 s = 3	 CNOTs = 77719	 depth = 758	 qubits = 8191
# 	 s = 4	 CNOTs = 62359	 depth = 762	 qubits = 5119
# 	 s = 5	 CNOTs = 51095	 depth = 790	 qubits = 3071
# 	 s = 6	 CNOTs = 43671	 depth = 874	 qubits = 1791
# 	 s = 7	 CNOTs = 39063	 depth = 1078	 qubits = 1023
# 	 s = 8	 CNOTs = 36311	 depth = 1530	 qubits = 575
# 	 s = 9	 CNOTs = 34711	 depth = 2486	 qubits = 319
# 	 s = 10	 CNOTs = 33799	 depth = 4458	 qubits = 175
# 	 s = 11	 CNOTs = 33287	 depth = 8470	 qubits = 95
# 	 s = 12	 CNOTs = 33003	 depth = 16570	 qubits = 51
# 	 s = 13	 CNOTs = 32847	 depth = 32854	 qubits = 27
# 	 s = 14	 CNOTs = 32762	 depth = 65513	 qubits = 14
#
# n = 15
# 	 s = 1	 CNOTs = 229264	 depth = 883	 qubits = 32767
# 	 s = 2	 CNOTs = 188304	 depth = 876	 qubits = 24575
# 	 s = 3	 CNOTs = 155536	 depth = 873	 qubits = 16383
# 	 s = 4	 CNOTs = 124816	 depth = 877	 qubits = 10239
# 	 s = 5	 CNOTs = 102288	 depth = 905	 qubits = 6143
# 	 s = 6	 CNOTs = 87440	 depth = 989	 qubits = 3583
# 	 s = 7	 CNOTs = 78224	 depth = 1193	 qubits = 2047
# 	 s = 8	 CNOTs = 72720	 depth = 1645	 qubits = 1151
# 	 s = 9	 CNOTs = 69520	 depth = 2601	 qubits = 639
# 	 s = 10	 CNOTs = 67696	 depth = 4573	 qubits = 351
# 	 s = 11	 CNOTs = 66672	 depth = 8585	 qubits = 191
# 	 s = 12	 CNOTs = 66104	 depth = 16685	 qubits = 103
# 	 s = 13	 CNOTs = 65792	 depth = 32969	 qubits = 55
# 	 s = 14	 CNOTs = 65620	 depth = 65629	 qubits = 29
# 	 s = 15	 CNOTs = 65530	 depth = 131048	 qubits = 15

# %% [markdown]
# # Plot

# %%
def plot(s, n_cx, n_dp, n_qb):
    # libraries
    import matplotlib.pyplot as plt
    import pandas as pd

    # data
    df=pd.DataFrame({ 'x_values': s, 'cnots': n_cx, 'depth': n_dp, 'qubits': n_qb })

    # multiple line plots
    plt.plot( 'x_values', 'cnots' , data=df, marker='o', markersize=8)
    plt.plot( 'x_values', 'depth' , data=df, marker='^', markersize=8)
    plt.plot( 'x_values', 'qubits', data=df, marker='s', markersize=8)
    # show legend
    plt.legend()
    
    # show graph
    plt.show()

def plot_result(n, result):
    s_range = [r[0] for r in result[n]]
    n_cx    = [r[1] for r in result[n]]
    n_dp    = [r[2] for r in result[n]]
    n_qb    = [r[3] for r in result[n]]

    plot(s_range, n_cx, n_dp, n_qb)

for n in range(3, 16):
    plot_result(n, result)
